# %%
#결국 시도도 못해본 결과물입니다.
#정확히는 받아온 정보에서 list에서 걸러낼 방법을 못찾았음......
#re.sub으로 정제하려는 부분은 하여간 다 틀렸어요.

import requests
from bs4 import BeautifulSoup
import urllib.request
from urllib.request import urlopen
import re
import sys
from urllib.parse import quote
import xlsxwriter

TARGET_URL_BEFORE_KEYWORD = "https://search.naver.com/search.naver?sm=tab_hty.top&where=post&query="
TARGET_URL_BEFORE_PAGE_NUMBER = '&oquery=&tqi=UaHyespySDCssbb3kMCsssssspl-053858&mson='

#정보들이 들어갈 리스트
URL_LIST=[]
IDS_LIST[]
VISITS=[]
TODAY_VISIT=[]
TOTAL_VISIT=[]
NEIGHBOR=[]
BLOG_URL=[]
INFO_LIST=[[IDS_LIST],[TODAY_VISIT],[TOTAL_VISIT],[NEIGHBOR]]


#주소를 확인하고 ID가 들어간 주소를 확보합니다.
def get_id_from_search_title(page_num, URL, output_file):
    for i in range(page_num):
        current_page_num = 1 + i*10
        position = URL.index('mson=') 
        URL_with_page_num = URL[: position+1] + str(current_page_num) \
                            + URL[position+1 :]
        source_code_from_URL = urllib.request.urlopen(URL_with_page_num)
        soup = BeautifulSoup(source_code_from_URL, 'lxml',
                             from_encoding='utf-8')
        #<div class="thumb thumb-rollover">
        for title in soup.find_all('div', 'thumb thumb-rollover'):
            title_link = title.select('a')
            article_URL = title_link[0]['href']
            get_text(article_URL, URL_LIST)

        #확보한 URL에서 ID를 뽑습니다.
            for IDS in URL_LIST:
                IDS=re.sub('https://blog.naver.com/', '', IDS)
                IDS=re.sub('Redirect=Log&logNo=', '', IDS)
                IDS=re.sub('[0-9][0-9][0-9][0-9][0-9][0-9][0-9][0-9][0-9][0-9][0-9][0-9]', '', IDS)
                IDS=re.sub('[%s]' % re.escape("""!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~"""), '', IDS)        
                IDS_LIST=[IDS]


#위의 함수에서 받은 ID로 블로그에서 정보를 크롤링하는 함수
def=get_information(IDS):                
    base_url = 'https://m.blog.naver.com/{}'

    for id in range (IDS):
        blog_url = base_url.format(id)
        webpage = urlopen(blog_url)
        source = BeautifulSoup(webpage, 'html5lib')
        VISITS = source.find_all('div', {'class':'count'})
            for TODAY_VISITS in VISITS:
                TODAY_VISITS=re.sub('[%s]' % re.escape(""" ", """), '', TODAY_VISITS)
                TODAY_VISITS=re.sub('오늘', '', TODAY_VISITS)
                TODAY_VISITS=re.sub('전체', '', TODAY_VISITS)
                TODAY_VISITS=re.findall(r"^\w+",TODAY_VISITS)
                
        NEIGHBOR = source.find_all('div', {'class':'count_buddy'})


#터미널로 실행시 보이는 메인 함수입니다.    
def main(argv):
    if len(argv) != 4:
        print("python [모듈이름] [검색을 원하는 키워드] [가져올 페이지 숫자 399까지] [결과 파일명]")
        return
    keyword = argv[1]
    page_num = int(argv[2])
    output_file_name = argv[3]
    target_URL = TARGET_URL_BEFORE_KEYWORD+quote(keyword)+TARGET_URL_BEFORE_PAGE_NUMBER
    #위의 함수들을 실행합니다
    get_link_from_news_title(page_num, target_URL, output_file)
    #그럼 이 결과물을 이제 xls 파일로 출력해보겠습니다.
    workbook = xlsxwriter.Workbook('Crawling_Results.xlsx')
    worksheet = workbook.add_worksheet()
    for item, cost in (INFO_LIST):
        worksheet.write(row, col,     item)
        worksheet.write(row, col + 1, cost)
        row += 1
        
        workbook.close()
    

print(get_ID(URL))
# Out:
#   File "<ipython-input-13-9672b6f6a05f>", line 13
#     ID_LIST=
#             ^
# SyntaxError: invalid syntax

# %%
#USER-AGENT
import requests
import random
user_agent_list = [
   #Chrome
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.113 Safari/537.36',
    'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.90 Safari/537.36',
    'Mozilla/5.0 (Windows NT 5.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.90 Safari/537.36',
    'Mozilla/5.0 (Windows NT 6.2; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.90 Safari/537.36',
    'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36',
    'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.113 Safari/537.36',
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/57.0.2987.133 Safari/537.36',
    'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/57.0.2987.133 Safari/537.36',
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/55.0.2883.87 Safari/537.36',
    'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/55.0.2883.87 Safari/537.36',
]
url = 'https://httpbin.org/user-agent'

for i in range(1,6):
    #Pick a random user agent
    user_agent = random.choice(user_agent_list)
    #Set the headers 
    headers = {'User-Agent': user_agent}
    #Make the request
    response = requests.get(url,headers=headers)
    
    print("Request #%d\nUser-Agent Sent:%s\nUser Agent Recevied by HTTPBin:"%(i,user_agent))
    print(response.content)
    print("-------------------\n\n")
# Out:
# Request #1
# User-Agent Sent:Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.113 Safari/537.36
# User Agent Recevied by HTTPBin:
# b'{\n  "user-agent": "Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.113 Safari/537.36"\n}\n'
# -------------------
#
#
# Request #2
# User-Agent Sent:Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.90 Safari/537.36
# User Agent Recevied by HTTPBin:
# b'{\n  "user-agent": "Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.90 Safari/537.36"\n}\n'
# -------------------
#
#
# Request #3
# User-Agent Sent:Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.113 Safari/537.36
# User Agent Recevied by HTTPBin:
# ...
